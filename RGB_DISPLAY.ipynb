# %% [markdown]
# <a href="https://colab.research.google.com/github/Srikarthikeyan4006/Artificial_Intelligence/blob/master/RGB_DISPLAY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import matplotlib.pyplot as plt
import numpy
from PIL import Image
numpy.set_printoptions(threshold=sys.maxsize)

# %%
img = cv2.imread('IMG_SK.jpg') 
img.shape
# Out:
# (1921, 1501, 3)

# %%
numpydata = asarray(img)

# %%
print("RED")
numpydata[0]
# Out:
# RED
# array([[100,  77,  81],
#        [118,  95,  99],
#        [146, 122, 124],
#        [165, 141, 141],
#        [171, 147, 147],
#        [174, 151, 149],
#        [182, 160, 155],
#        [191, 169, 164],
#        [211, 187, 181],
#        [212, 188, 182],
#        [216, 193, 185],
#        [225, 202, 194],
#        [217, 191, 184],
#        [221, 195, 188],
#        [224, 198, 191],
#        [227, 201, 194],
#        [227, 199, 192],
#        [228, 200, 193],
#        [229, 201, 194],
#        [231, 203, 196],
#        [233, 205, 198],
#        [233, 205, 198],
#        [233, 205, 198],
#        [232, 204, 197],
#        [231, 203, 196],
#        [231, 203, 196],
#        [231, 203, 196],
#        [229, 201, 194],
#        [230, 202, 195],
#        [234, 206, 199],
#        [236, 208, 201],
#        [237, 209, 202],
#        [230, 202, 195],
#        [229, 201, 194],
#        [231, 203, 196],
#        [235, 207, 200],
#        [238, 210, 203],
#        [236, 208, 201],
# ...

# %%
print("GREEN")
numpydata[1]
# Out:
# GREEN
# array([[105,  82,  86],
#        [116,  93,  97],
#        [140, 116, 118],
#        [163, 139, 139],
#        [174, 150, 150],
#        [176, 153, 151],
#        [184, 162, 157],
#        [195, 173, 168],
#        [215, 191, 185],
#        [217, 193, 187],
#        [219, 196, 188],
#        [227, 204, 196],
#        [223, 197, 190],
#        [226, 200, 193],
#        [226, 200, 193],
#        [228, 202, 195],
#        [231, 203, 196],
#        [232, 204, 197],
#        [234, 206, 199],
#        [235, 207, 200],
#        [234, 206, 199],
#        [233, 205, 198],
#        [234, 206, 199],
#        [234, 206, 199],
#        [236, 208, 201],
#        [237, 209, 202],
#        [237, 209, 202],
#        [235, 207, 200],
#        [236, 208, 201],
#        [238, 210, 203],
#        [238, 210, 203],
#        [238, 210, 203],
#        [232, 204, 197],
#        [232, 204, 197],
#        [235, 207, 200],
#        [239, 211, 204],
#        [240, 212, 205],
#        [237, 209, 202],
# ...

# %%
print("BLUE")
numpydata[2]
# Out:
# BLUE
# array([[108,  85,  89],
#        [113,  90,  94],
#        [131, 109, 111],
#        [156, 135, 134],
#        [172, 148, 148],
#        [176, 153, 151],
#        [183, 161, 156],
#        [193, 171, 166],
#        [208, 184, 178],
#        [214, 190, 184],
#        [216, 193, 185],
#        [226, 203, 195],
#        [229, 203, 196],
#        [231, 205, 198],
#        [226, 200, 193],
#        [229, 203, 196],
#        [229, 203, 196],
#        [232, 206, 199],
#        [234, 208, 201],
#        [233, 207, 200],
#        [231, 205, 198],
#        [230, 204, 197],
#        [232, 206, 199],
#        [234, 208, 201],
#        [235, 209, 202],
#        [236, 210, 203],
#        [236, 210, 203],
#        [235, 209, 202],
#        [235, 209, 202],
#        [235, 209, 202],
#        [234, 208, 201],
#        [233, 207, 200],
#        [231, 205, 198],
#        [232, 206, 199],
#        [235, 209, 202],
#        [237, 211, 204],
#        [237, 211, 204],
#        [234, 208, 201],
# ...

# %%
w, h = 512, 512
data = np.zeros((h, w, 3), dtype=np.uint8)
data[0:256, 0:256] = [200, 100, 10] 
img = Image.fromarray(data, 'RGB')

# %%
imgplot = plt.imshow(img)
plt.show()
